# %%
# !git clone https://github.com/chankiel/Steam-Review-NLP-Pipeline.git
# %cd Steam-Review-NLP-Pipeline
# Out:
# fatal: destination path 'Steam-Review-NLP-Pipeline' already exists and is not an empty directory.
# /content/Steam-Review-NLP-Pipeline

# %%
# !git pull
# Out:
# Already up to date.

# %%
import sys
sys.path.append('/content/Steam-Review-NLP-Pipeline')

# %%
import pandas as pd
from src.utils.config import get_config
from src.training.datasets.absa_dataset import ABSADataset
from src.training.models.absa_model import ABSAModel
from src.training.trainers.absa_trainer import train, evaluate
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(

# %%
# https://drive.google.com/file/d/1MuTXk0_OPOT_cgL10DI-z5EZR545CdWh/view?usp=sharing
# https://drive.google.com/file/d/1aBkHVr5dD8FjI5HhGZZCThCrt4_6Fk09/view?usp=sharing

train_df = pd.read_csv('https://drive.google.com/uc?id=1MuTXk0_OPOT_cgL10DI-z5EZR545CdWh')
val_df = pd.read_csv('https://drive.google.com/uc?id=1aBkHVr5dD8FjI5HhGZZCThCrt4_6Fk09')

# %%
absa_model = train(train_df,val_df)
# Out:
# Epoch 1/3 - Train Loss: 0.5360
# Validation Accuracy: 0.8542
# Epoch 2/3 - Train Loss: 0.3616
# Validation Accuracy: 0.8670
# Epoch 3/3 - Train Loss: 0.2743
# Validation Accuracy: 0.8788
# Model saved to ./outputs/absa_model.pt
