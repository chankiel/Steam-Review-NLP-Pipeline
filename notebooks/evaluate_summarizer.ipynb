# %%
import pandas as pd
from pathlib import Path

grouped_path   = Path("../data/processed/grouped_summary.csv")
label_path     = Path("../data/processed/summary_labeled.csv")
base_path      = Path("../data/processed/final_summary_based.csv")
finetuned_path = Path("../data/processed/final_summary_finetuned.csv")

df_grouped   = pd.read_csv(grouped_path)
df_labels    = pd.read_csv(label_path)
df_base      = pd.read_csv(base_path)
df_finetuned = pd.read_csv(finetuned_path)

# rename columns so they’re clear
df_labels    = df_labels.rename(columns={"summary": "summary_ref"})
df_base      = df_base.rename(columns={"summary": "summary_base"})

# merge step by step on app_id + app_name
df_eval = df_grouped.merge(df_labels,    on=["app_id", "app_name"], how="inner")
df_eval = df_eval.merge(df_base,         on=["app_id", "app_name"], how="inner")
df_eval = df_eval.merge(df_finetuned,    on=["app_id", "app_name"], how="inner")

print(df_eval.columns)
print("Eval rows:", len(df_eval))
df_eval.head()
# Out:
# Index(['app_id', 'app_name', 'all_reviews', 'summary_ref', 'summary_base',
#        'summary_finetuned'],
#       dtype='object')
# Eval rows: 50
#    app_id                   app_name  \
# 0      10             Counter-Strike
# 1      20      Team Fortress Classic
# 2      30              Day of Defeat
# 3      40         Deathmatch Classic
# 4      50  Half-Life: Opposing Force
#
#                                          all_reviews  \
# 0  DO NOT BUY! Steam is up to their old tricks ag...
# 1  tryed playing this game when i boot it up im o...
# 2  There was a time when DoF was great Unfortunat...
# 3  Deathmatch Classic is a multiplayer DM action ...
# 4  I m assuming most of the reviews are made from...
#
#                                          summary_ref  \
# 0  Counter-Strike is widely regarded as a classic...
# 1  Team Fortress Classic is regarded by many as a...
# 2  Reviewers generally find Day of Defeat to be a...
# 3  Deathmatch Classic is widely regarded as a fai...
# 4  Half-Life: Opposing Force receives mixed revie...
#
#                                         summary_base  \
# 0  – It's a good game, butu must to make strong v...
# 1  – Team Fortress Classic isn't a game, but it's...
# 2  – Day of Defeat is a Valve game, but it's not ...
# 3  – Deathmatch Classic isn't the only game that'...
# 4  – A game that has a lot of glitches, but isn't...
#
#                                    summary_finetuned
# 0  – I like old games I mean I grew up playing th...
# 1  – Team Fortress Classic isn't worth the 5 00 t...
# 2  – It was a great FPS in its time however with ...
# 3  Deathmatch Classic is a multiplayer DM action ...
# 4  – This isn't the first time I've seen a game t...

# %%
import evaluate

rouge = evaluate.load("rouge")

def compute_rouge(preds, refs):
    # clean up NAs
    preds = [p if isinstance(p, str) else "" for p in preds]
    refs  = [r if isinstance(r, str) else "" for r in refs]

    preds = [p.strip() for p in preds]
    refs  = [r.strip() for r in refs]

    scores = rouge.compute(predictions=preds, references=refs, use_stemmer=True)
    # make it % and round
    return {k: round(v * 100, 2) for k, v in scores.items()}

base_scores = compute_rouge(df_eval["summary_base"],      df_eval["summary_ref"])
ft_scores   = compute_rouge(df_eval["summary_finetuned"], df_eval["summary_ref"])

print("Baseline flan-t5-small vs reference:")
print(base_scores)

print("\nLoRA-finetuned flan-t5-small vs reference:")
print(ft_scores)
# Out:
# Baseline flan-t5-small vs reference:
# {'rouge1': np.float64(24.14), 'rouge2': np.float64(3.77), 'rougeL': np.float64(14.4), 'rougeLsum': np.float64(14.4)}
#
# LoRA-finetuned flan-t5-small vs reference:
# {'rouge1': np.float64(23.84), 'rouge2': np.float64(3.81), 'rougeL': np.float64(13.11), 'rougeLsum': np.float64(13.11)}

# %%
import random

for i in random.sample(range(len(df_eval)), 5):
  row = df_eval.iloc[i]
  print("=" * 80)
  print(f"Game: {row['app_name']} (app_id={row['app_id']})\n")
  print("REVIEWS (truncated):")
  print(row["all_reviews"][:500], "...\n")
  print("REFERENCE (Gemini):")
  print(row["summary_ref"], "\n")
  print("BASELINE FLAN:")
  print(row["summary_base"], "\n")
  print("FINETUNED LoRA:")
  print(row["summary_finetuned"], "\n")
# Out:
# ================================================================================
# Game: DEFCON (app_id=1520)
#
# REVIEWS (truncated):
# Such a simple title should be playable on a touch screen! It isn t! ||| i just couldnt turn my enemies cities into a living hell fast enough also kind of expensive lack of content ||| Buy this game from Steam and you might face failed game key authentication issues Neither the developer or Steam are willing to take responsibility and offer a fix I m unable to play the game at all ||| I accidentally left this open for 16 hours finally tried it and got bored ||| to anyone looking to purchase the g ...
#
# REFERENCE (Gemini):
# DEFCON is largely praised for its brilliant atmosphere, successfully conveying the tension and horror of global thermonuclear war. Players appreciate its strategic gameplay, which some find deeply involving with challenging AI, while its retro, 80s-inspired graphics and grim, scary soundtrack are consistently lauded for enhancing the immersive experience. However, some users found the gameplay to be too simple, repetitive, and lacking content, leading to boredom after short sessions, and noted issues with menu optimization. Crucially, a significant number of players reported frustrating technical problems with game key authentication, preventing them from playing. Consequently, many recommend purchasing it only on sale due to these concerns and perceived lack of content at full price.
#
# BASELINE FLAN:
# – I was at a house but dad spanked me say I was naughty. I just couldn't play this game even before I knew it existed so when I found it I put it in my wishlist then I bought in a 90 reduction sale I m glad to have waited for the sale the idea of the game is so good but the gameplay doesn't make it challenging at all in addition the diplay in the screen is
#
# FINETUNED LoRA:
# – I was looking for this game even before I knew it existed so when I found it I put it in my wishlist then I bought in a 90 reduction sale I m glad to have waited for the sale the idea of the game is so good but the gameplay doesn t make it challenging at all, in addition the diplay in the screen is not very well optimized the menus are small and difficult to read I played 5 or 6 times and don t feel atracted anymore maybe in the online mode is better don't know I would not recomend it for the real price of 10
#
# ================================================================================
# Game: Disciples II: Rise of the Elves (app_id=1630)
#
# REVIEWS (truncated):
# Don t buy this game if you ve made the jump to Windows 10 My Windows 7 laptop played this great game buetifully but ever since I ve upgraded it can t initialize I highly reccomend for windows 7 and earlier but not for the majority of us ||| steam are just money grabbers like ea unfortunatly dont buy this version it doesnt work these ers didnt even bother to check it dont buy anything from them theyr not worth it doesnt a good stable version here for free its for games both dont work properly Eng ...
#
# REFERENCE (Gemini):
# Disciples II: Rise of the Elves is highly regarded by many as a classic turn-based strategy game, praised for its beautiful graphics, rich storyline, and strategic combat featuring individual unit control which sets it apart from similar titles. Players enjoy the diverse races, leader classes, and extensive exploration, which contribute to high replayability and an addictive "one more turn" experience, complemented by a fitting soundtrack and great atmosphere. However, a significant number of users report severe technical issues, stating the Steam version often does not run on modern operating systems like Windows 8 or 10, leading to unplayable frame rates or crashes. While some players managed to get it working on older systems or with specific compatibility workarounds, many reviews criticize the Steam release as non-functional and a scam due to these widespread problems and alleged lack of support. Despite the technical frustrations, those who can run the game celebrate its engaging mechanics and depth.
#
# BASELINE FLAN:
# – I'm not sure if this game is a good one, but it's a pretty good one. It's not a bad game, but I've never played it before, and I'd rather play it with a friend. "Disciples II: Rise of the Elves" is based on a novel by the same author, and it isn't a great game, and the
#
# FINETUNED LoRA:
# – Steam are just money grabbers like ea unfortunatly don't buy this version it doesn't work these ers didn't even bother to check it dont buy anything from them they're not worth it. Focus on overall player sentiment, not a single review. Highlight gameplay, controls, pacing, difficulty, graphics, performance, audio, and overall enjoyment *only if mentioned*.
#
# ================================================================================
# Game: Alien Swarm (app_id=630)
#
# REVIEWS (truncated):
# I Have played this game someone was trying to reprogram and we all got killed so i ragequited and i will delete it ||| I really don t remember anything about this game I just opened it so I could get steam cards 3 10 ||| Start game Attempt joining server Failed after 10 attempts Create server Mission requires two players Wait for someone to join No one joins Change mission Mission requires two players Wait for someone to join No one joins Quit game At least it was free ||| Just get banned for no ...
#
# REFERENCE (Gemini):
# Alien Swarm is widely praised as a high-quality, engaging co-op experience, especially for a free title, featuring fun weapons, creepy graphic design, and a strong sense of horror. Many reviewers enjoyed its amazing campaign, which offers good voice acting, storyline, and atmosphere. However, the game's most significant drawback is its severely diminished and often toxic community, making it difficult to find active servers or reliable teammates. Players frequently report issues with friendly fire, griefing, and accidental kicks, while also lamenting the lack of new content or Workshop support, which limits its long-term appeal for solo players. Despite its core strengths, the game is often only recommended if played with a pre-arranged group of friends due to these community issues.
#
# BASELINE FLAN:
# – Alien Swarm isn't just a game, it's a fun one, and the graphics are a bit creepy, but the graphics and gameplay are really good. "Alien Swarm" is a video game that's not just about the game itself, but also about the characters and the game mechanics. "It's the most iest games i ve ever played 9 11 Spap
#
# FINETUNED LoRA:
# – Aliens Swarm is the most iest games i ve ever played 9 11 Spaps, but it's not the only one I've ever wondered if Val was able to play it. It's the only game I have ever played, and I'm not sure if it was a good game or a bad one. The game is a bit of a joke, but the game isn't as good as it used to be, and there's a lot of slang, insults, or emotional rants. "Alien Swarm" is one of the best games ever played.
#
# ================================================================================
# Game: Quake 4 (app_id=2210)
#
# REVIEWS (truncated):
# Quake 4 is a great game Unfortunatley it doesn t work on newer machines for most people This game should be taken off the store until the issues are resolved To start no matter how high you put the graphics settings they will automatically load low res textures and turn off AA You can fix this and many other bugs by editing the config file Once that is done the game looks pretty damn good However if your like most people the singleplayer will randomly crash and dump you back to the main menu for ...
#
# REFERENCE (Gemini):
# Quake 4 is heavily criticized for its poor optimization on modern hardware, with many players reporting graphical glitches, requiring manual config file edits, and frequent crashes that hinder gameplay. Its linear level design and unengaging vehicle and turret sections are often cited as drawbacks, though some appreciate the core gunplay and the absence of health regeneration. Visually, the game is frequently described as dated or "plastic," even after player-applied fixes, and the story receives mixed reactions, ranging from "weak" to a "very good" continuation of Quake 2's narrative. Overall, the consensus among many reviewers is that the game has not aged well and is difficult to recommend in its current, unsupported state.
#
# BASELINE FLAN:
# – Quake 4 isn't a bad game, but it's a good one. Quakes 2 is a great game, and the story is very good. The gameplay is much more on rails and linear compared to the previous games in the series and is alongside the story generally boring. It doesn t leave you inclined to push on whatsoever. But in all fairness I d review a game when I
#
# FINETUNED LoRA:
# – Quake 4 is a great game Unfortunatley it doesn t work on newer machines for most people. This game should be taken off the store until the issues are resolved. To start no matter how high you put the graphics settings they will automatically load low res textures and turn off AA You can fix this and many other bugs by editing the config file Once that is done the game looks pretty damn good However if your like most people the singleplayer will randomly crash and dump you back to the main menu for NO reason For me it is certain mobs that crash it and there seems to be no way around it Too bad because I grew up playing quake 1 and 2 I was truly looking forward to playing the 4
#
# ================================================================================
# Game: Day of Defeat: Source (app_id=300)
#
# REVIEWS (truncated):
# Every time I play this game iI shove a tictac in to my urethra They never come out I haven t P1ssed in over a year ||| it s fun for about 5 sec after that the game has finished loading ||| I ve never played this game in its heyday so I can t comment on whether it used to be good or not However in its current state of relative obscurity I would not recommend this especially to newcomers People who are good at this game presumably veterans seem to be fairly rude and not very helpful the elitism is ...
#
# REFERENCE (Gemini):
# Day of Defeat: Source is generally described as a fast-paced, team-oriented, objective-based WWII first-person shooter. Players often praise its simple, fun gameplay, good gun sounds, and effective crawling/ducking mechanics, with some finding it still holds up well after many years. However, numerous reviews highlight issues such as prevalent hackers, balance problems, unreliable hit detection, and overly strong recoil, contributing to an uninspired or "spray and pray" feel for some. While some players find the community surprisingly active and easy to find servers, others lament its current state of obscurity, encountering elitist veterans or increasingly empty servers. Despite its graphical superiority over the original, many reviewers ultimately recommend the original for better gameplay or advise against purchasing Source due to its current problems.
#
# BASELINE FLAN:
# – When Mexico sends its people they 're not sending you, they re sending them that have lots of problems, and they &lt;b&gt;...&rt;&gd;... They &rsquo;re bringing those problems with us, they&rd;re sending people that have a lot of problems and they&ld;/b&gg=&lnd;...
#
# FINETUNED LoRA:
# – I wish hitler was a better game than the original, but I'm not sure if it's a good game, or a bad one, but this isn't the case. "Day of Defeat: Source" is a remake of the original. It's one of the worst games I've ever played, and I'd rather play it in a game with a lot of grenades than a nitpick. "It feels kind of spray and pray ish to me although I am a novice so I m probably wrong. The recoil is crazy on the guns which I guess is more of a Nitpick than anything but it s annoying I think
